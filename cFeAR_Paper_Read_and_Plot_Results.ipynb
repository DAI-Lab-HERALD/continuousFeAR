# %%
# %%capture
# %matplotlib inline


import ContinuousFeAR as cfear
import Plot_cFeAR as plotcf

import os

Plot_All = False
Plot_All = True

Save_Figs = True
# Save_Figs = False

PLOT_FROM_LIST = True
# PLOT_FROM_LIST = False

plot_feasible_action_and_cofiguration_spaces_ = False
# plot_feasible_action_and_cofiguration_spaces_ = True

folder = 'FeAR_Results'

# %% [markdown]
# # Forward-Looking and Backward-Looking Responsibility

# %%
file = '8Agents_RoundAbout_Intersection_compact_13-a_num-2024-10-16_01-17-14.pkl'
results_file_path = os.path.join(folder,file)
print(f'{results_file_path=}')

plot_feasible_action_and_cofiguration_spaces_ = False
# plot_feasible_action_and_cofiguration_spaces_ = True

cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                            scale_scenario_size=1, scale_velocities=4,
                            plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                            fear_threshold=0.15,
                            fear_cbar=True,
                            highlight_agents=[2,3,4,5],
                            animate=True)
print("Done!")

# %% [markdown]
#  # Running Example

# %%
file = 'Collision_Check_Illustration_2Agents_U_turn_2-a_num-2025-01-06_00-04-50.pkl'
results_file_path = os.path.join(folder,file)
print(f'{results_file_path=}')

arrow_width = 0.45
arrow_markersize = 10


plot_feasible_action_and_cofiguration_spaces_ = True
plot_feasible_action_and_cofiguration_spaces_ = False


cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                            scale_scenario_size=1, scale_velocities=3,
                            arrow_width=arrow_width, arrow_markersize=arrow_markersize,
                            plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                            fear_threshold=0.15,fear_cbar=True, animate=True,
                            place_scenario_legend = 'extend_right_out')

print('Done!')

# %% [markdown]
# # Prototypical Space-Sharing Conflicts

# %%
plot_feasible_action_and_cofiguration_spaces_ = True
plot_feasible_action_and_cofiguration_spaces_ = False



arrow_width = 0.95
arrow_markersize = 12
scale_velocities = 4

if PLOT_FROM_LIST or PLOT_FROM_FIRST_LIST:

    files = [
        'CS1_lane_CC-a_num-2024-08-27_23-29-50.pkl',
        'CS2_lane_AC-a_num-2024-08-28_00-33-48.pkl',
        'CS11_parallel-a_num-2025-04-10_19-09-49.pkl'    ]
    

    for file in files:
        results_file_path = os.path.join(folder,file)
        print(f'{results_file_path=}')
        cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                    scale_scenario_size=1, scale_velocities=scale_velocities,
                                    arrow_width=arrow_width, arrow_markersize=arrow_markersize,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=False,
                                    fear_bar_plot_indices=None,
#                                     place_scenario_legend = 'left_out'
                                    place_scenario_legend = 'skip'
                                   )
#     plot_feasible_action_and_cofiguration_spaces_ = True
    files = [
        'CS3_lane_AA-a_num-2025-02-11_12-31-34.pkl',
    ]
    
    for file in files:
        results_file_path = os.path.join(folder,file)
        print(f'{results_file_path=}')
        cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                    scale_scenario_size=1, scale_velocities=scale_velocities,
                                    arrow_width=0.85, arrow_markersize=15,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=False,
                                    fear_bar_plot_indices=None,
#                                     place_scenario_legend = 'extend_right_out'
                                    place_scenario_legend = 'skip'
                               )
#     plot_feasible_action_and_cofiguration_spaces_ = False
    
    
    files = [ 
        'CS7_lane_obstacle-a_num-2024-08-28_00-48-06.pkl'
    ]
    

    for file in files:
        results_file_path = os.path.join(folder,file)
        print(f'{results_file_path=}')
        cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                    scale_scenario_size=1, scale_velocities=scale_velocities,
                                    arrow_width=1.05, arrow_markersize=10,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=False,
                                    fear_bar_plot_indices=None,
#                                     place_scenario_legend = 'left_out'
                                    place_scenario_legend = 'skip'
                                   )
    files = [ 
#         'CS9_crossing_slow_assertive-a_num-2024-08-28_01-23-05.pkl',
        'CS10_crossing_fast_courteous-a_num-2024-08-28_01-18-25.pkl',
    ]
    

    for file in files:
        results_file_path = os.path.join(folder,file)
        print(f'{results_file_path=}')
        cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                    scale_scenario_size=1, scale_velocities=scale_velocities,
                                    arrow_width=arrow_width, arrow_markersize=arrow_markersize,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=False,
                                    fear_bar_plot_indices=None,
#                                     place_scenario_legend = 'right_in'
                                    place_scenario_legend = 'skip'
                                   )
        
        files = [ 
        'CS9_crossing_slow_assertive-a_num-2024-08-28_01-23-05.pkl',
#         'CS10_crossing_fast_courteous-a_num-2024-08-28_01-18-25.pkl',
    ]
    

    for file in files:
        results_file_path = os.path.join(folder,file)
        print(f'{results_file_path=}')
        cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                    scale_scenario_size=0.45, scale_velocities=scale_velocities,
                                    arrow_width=arrow_width, arrow_markersize=arrow_markersize,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=False,
                                    fear_bar_plot_indices=None,
#                                     place_scenario_legend = 'extend_right_out'
                                    place_scenario_legend = 'skip'
                                   )
        
            
print("Done!")

# %%
plot_feasible_action_and_cofiguration_spaces_ = False
# plot_feasible_action_and_cofiguration_spaces_ = True


arrow_width = 0.75
arrow_markersize = 12
scale_velocities = 4

if PLOT_FROM_LIST or PLOT_FROM_FIRST_LIST:


    files = [
        'CS4_intersection_collision_12-a_num-2025-04-17_14-47-52.pkl',
        'CS5_intersection_collision_00-a_num-2025-04-17_14-50-57.pkl',
        'CS6_intersection_collision_23-a_num-2025-04-17_14-51-59.pkl'
    ]
    

    for file in files:
        results_file_path = os.path.join(folder,file)
        print(f'{results_file_path=}')
        cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                    scale_scenario_size=1, scale_velocities=scale_velocities,
                                    arrow_width=arrow_width, arrow_markersize=arrow_markersize,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=False,
                                    fear_bar_plot_indices=None,
#                                     place_scenario_legend = 'left_out'
                                    place_scenario_legend = 'skip'
                                   )
        
        
        files = [
        'CS8_intersection_obstacles-a_num-2025-04-17_14-54-31.pkl'
    ]
    

    for file in files:
        results_file_path = os.path.join(folder,file)
        print(f'{results_file_path=}')
        cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                    scale_scenario_size=1, scale_velocities=scale_velocities,
                                    arrow_width=0.85, arrow_markersize=arrow_markersize,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=False,
                                    fear_bar_plot_indices=None,
#                                     place_scenario_legend = 'left_in'
                                    place_scenario_legend = 'skip'
                                   )
        
        
    files = [
        'CS12_causal_overdeterminism-a_num-2024-08-28_01-32-13.pkl'
    ]
    

    for file in files:
        results_file_path = os.path.join(folder,file)
        print(f'{results_file_path=}')
        cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                    scale_scenario_size=1, scale_velocities=scale_velocities,
                                    arrow_width=arrow_width, arrow_markersize=arrow_markersize,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=False,
                                    fear_bar_plot_indices=None,
                                    place_scenario_legend = 'skip'
#                                     place_scenario_legend = 'up'
                                    
                                   )
        
            
print("Done!")

# %% [markdown]
# # MdR Cases

# %%
plot_feasible_action_and_cofiguration_spaces_ = False
# plot_feasible_action_and_cofiguration_spaces_ = True



mdr_cases = [        
        {'file':'3Agents_MdR_1-compute_mdrs-2024-10-23_14-32-06.pkl', 'legend':'skip', 'panels':None}
        ,
        {'file':'3Agents_MdR_2-compute_mdrs-2024-10-23_14-33-19.pkl', 'legend':'skip',  'panels':['','A','B','C','']}
        ,
        {'file':'3Agents_MdR_3-compute_mdrs-2024-10-23_14-34-34.pkl', 'legend':'left_out',  'panels':['','D','E','F','']}
        ,
        {'file':'3Agents_MdR_4-compute_mdrs-2024-10-23_14-36-10.pkl', 'legend':'skip',  'panels':['','G','H','I','']}
        ,
        {'file':'3Agents_MdR_5-compute_mdrs-2024-10-23_14-37-27.pkl', 'legend':'skip',  'panels':None}        
    ]

for case in mdr_cases:
    file = case['file']
    legend_ = case['legend']
    panels = case['panels']
    
    print(f'{file=}, {legend_=}, {panels=} ')
    
    results_file_path = os.path.join(folder,file)
    print(f'{results_file_path=}')
    cfear.read_and_plot_results(results_file_path=results_file_path, plot_scenario=True,save_figs=Save_Figs,
                                scale_scenario_size=1, scale_velocities=2,
                                    plot_feasible_action_and_cofiguration_spaces_=plot_feasible_action_and_cofiguration_spaces_,
                                    fear_threshold=0.15,
                                    fear_bar_plot=True,
                                    fear_bar_plot_indices=[[0,1],[0,2],[1,0],[2,0]],
                                    fear_bar_plot_panel_text = panels,
                                    place_scenario_legend = legend_
                                   )

# %%
print('Done!')
